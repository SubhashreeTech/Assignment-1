# %%
import pandas as pd

# File path
vep_file = "/home/subhashree/Project/CTX-Bioinformatics-Intern-Assignment/test2_data_1_vep.tsv"

# Read VEP TSV file and skip '##' metadata lines
df_raw = pd.read_csv(
    vep_file,
    sep="\t",
    comment='##',  # skip metadata lines
    engine='python'
)

# Remove leading '#' from header if present
df_raw.rename(columns=lambda x: x.lstrip('#'), inplace=True)

# Save cleaned dataframe starting from '#Uploaded_variation'
df = df_raw.copy()
df.head()
# Out:
#   Uploaded_variation Location Allele             Gene          Feature  \
# 0          rs3087742    MT:73      G  ENSG00000198888  ENST00000361390
# 1          rs3087742    MT:73      G  ENSG00000198763  ENST00000361453
# 2          rs3087742    MT:73      G  ENSG00000209082  ENST00000386347
# 3          rs3087742    MT:73      G  ENSG00000210049  ENST00000387314
# 4          rs3087742    MT:73      G  ENSG00000210077  ENST00000387342
#
#   Feature_type            Consequence cDNA_position CDS_position  \
# 0   Transcript  upstream_gene_variant             -            -
# 1   Transcript  upstream_gene_variant             -            -
# 2   Transcript  upstream_gene_variant             -            -
# 3   Transcript  upstream_gene_variant             -            -
# 4   Transcript  upstream_gene_variant             -            -
#
#   Protein_position  ... MAX_AF_POPS CLIN_SIG SOMATIC PHENO  \
# 0                -  ...           -        -       -     -
# 1                -  ...           -        -       -     -
# 2                -  ...           -        -       -     -
# 3                -  ...           -        -       -     -
# 4                -  ...           -        -       -     -
#
#                                 PUBMED MOTIF_NAME MOTIF_POS HIGH_INF_POS  \
# 0  34002094,35453788,37998725,37881602          -         -            -
# 1  34002094,35453788,37998725,37881602          -         -            -
# 2  34002094,35453788,37998725,37881602          -         -            -
# 3  34002094,35453788,37998725,37881602          -         -            -
# 4  34002094,35453788,37998725,37881602          -         -            -
#
#   MOTIF_SCORE_CHANGE TRANSCRIPTION_FACTORS
# 0                  -                     -
# 1                  -                     -
# 2                  -                     -
# 3                  -                     -
# 4                  -                     -
#
# [5 rows x 82 columns]

# %%
# Total variants
total_variants = len(df)
print("Total variants:", total_variants)

# Unique genes
unique_genes = df['Gene'].nunique()
print("Unique genes:", unique_genes)
# Out:
# Total variants: 4447820
# Unique genes: 67066

# %%
# Extract traits from PHENO column
phenos = df['PHENO'].dropna().astype(str)
unique_traits = set()
for p in phenos:
    for trait in p.replace(';', ',').split(','):
        trait = trait.strip()
        if trait:
            unique_traits.add(trait)

num_unique_traits = len(unique_traits)
print("Unique traits/disease conditions:", num_unique_traits)
# Out:
# Unique traits/disease conditions: 3

# %%
df["CLIN_SIG"].value_counts()
# Out:
# -                                                                                             4433710
# benign                                                                                           5510
# likely_benign                                                                                    1601
# uncertain_significance                                                                           1534
# pathogenic                                                                                        915
#                                                                                                ...
# pathogenic,pathogenic/likely_pathogenic,not_provided                                                8
# likely_benign,uncertain_significance,conflicting_interpretations_of_pathogenicity                   8
# risk_factor,affects,pathogenic,pathogenic/likely_pathogenic,likely_pathogenic,not_provided          2
# not_provided,likely_benign                                                                          2
# risk_factor                                                                                         2
# Name: CLIN_SIG, Length: 97, dtype: int64

# %%
df_patho = df[df["CLIN_SIG"].str.contains("pathogenic", case=False, na=False)]
df_patho
# Out:
#         Uploaded_variation     Location Allele             Gene  \
# 283            rs387906735       MT:608      G  ENSG00000198888
# 284            rs387906735       MT:608      G  ENSG00000198763
# 285            rs387906735       MT:608      G  ENSG00000209082
# 286            rs387906735       MT:608      G  ENSG00000210049
# 287            rs387906735       MT:608      G  ENSG00000210077
# ...                    ...          ...    ...              ...
# 4301254          rs1555050  22:50627253      T  ENSG00000289244
# 4301255          rs1555050  22:50627253      T  ENSG00000289244
# 4301256          rs1555050  22:50627253      T  ENSG00000289244
# 4301257          rs1555050  22:50627253      T  ENSG00000289244
# 4301258          rs1555050  22:50627253      T  ENSG00000289244
#
#                  Feature Feature_type                         Consequence  \
# 283      ENST00000361390   Transcript               upstream_gene_variant
# 284      ENST00000361453   Transcript               upstream_gene_variant
# 285      ENST00000386347   Transcript               upstream_gene_variant
# 286      ENST00000387314   Transcript  non_coding_transcript_exon_variant
# 287      ENST00000387342   Transcript               upstream_gene_variant
# ...                  ...          ...                                 ...
# 4301254  ENST00000806467   Transcript               upstream_gene_variant
# 4301255  ENST00000806468   Transcript               upstream_gene_variant
# 4301256  ENST00000806469   Transcript               upstream_gene_variant
# 4301257  ENST00000806470   Transcript               upstream_gene_variant
# 4301258  ENST00000806471   Transcript               upstream_gene_variant
#
#         cDNA_position CDS_position Protein_position  ...  \
# 283                 -            -                -  ...
# 284                 -            -                -  ...
# 285                 -            -                -  ...
# 286                32            -                -  ...
# 287                 -            -                -  ...
# ...               ...          ...              ...  ...
# 4301254             -            -                -  ...
# 4301255             -            -                -  ...
# 4301256             -            -                -  ...
# 4301257             -            -                -  ...
# 4301258             -            -                -  ...
#
#                                                MAX_AF_POPS  \
# 283                                                      -
# 284                                                      -
# 285                                                      -
# 286                                                      -
# 287                                                      -
# ...                                                    ...
# 4301254  gnomADe_AFR,gnomADe_AMR,gnomADe_ASJ,gnomADe_EA...
# 4301255  gnomADe_AFR,gnomADe_AMR,gnomADe_ASJ,gnomADe_EA...
# 4301256  gnomADe_AFR,gnomADe_AMR,gnomADe_ASJ,gnomADe_EA...
# 4301257  gnomADe_AFR,gnomADe_AMR,gnomADe_ASJ,gnomADe_EA...
# 4301258  gnomADe_AFR,gnomADe_AMR,gnomADe_ASJ,gnomADe_EA...
#
#                                   CLIN_SIG SOMATIC PHENO    PUBMED MOTIF_NAME  \
# 283      uncertain_significance,pathogenic       -     1  11231339          -
# 284      uncertain_significance,pathogenic       -     1  11231339          -
# 285      uncertain_significance,pathogenic       -     1  11231339          -
# 286      uncertain_significance,pathogenic       -     1  11231339          -
# 287      uncertain_significance,pathogenic       -     1  11231339          -
# ...                                    ...     ...   ...       ...        ...
# 4301254                         pathogenic     0,1   1,1         -          -
# 4301255                         pathogenic     0,1   1,1         -          -
# 4301256                         pathogenic     0,1   1,1         -          -
# 4301257                         pathogenic     0,1   1,1         -          -
# 4301258                         pathogenic     0,1   1,1         -          -
#
#         MOTIF_POS HIGH_INF_POS MOTIF_SCORE_CHANGE TRANSCRIPTION_FACTORS
# 283             -            -                  -                     -
# 284             -            -                  -                     -
# 285             -            -                  -                     -
# 286             -            -                  -                     -
# 287             -            -                  -                     -
# ...           ...          ...                ...                   ...
# 4301254         -            -                  -                     -
# 4301255         -            -                  -                     -
# 4301256         -            -                  -                     -
# 4301257         -            -                  -                     -
# 4301258         -            -                  -                     -
#
# [3525 rows x 82 columns]

# %%
df_likely_patho = df[df["CLIN_SIG"].str.contains("likely_pathogenic", case=False, na=False)]
df_likely_patho
# Out:
#         Uploaded_variation    Location Allele             Gene  \
# 2501           rs199474657     MT:3243      G  ENSG00000198888
# 2502           rs199474657     MT:3243      G  ENSG00000198763
# 2503           rs199474657     MT:3243      G  ENSG00000198804
# 2504           rs199474657     MT:3243      G  ENSG00000198712
# 2505           rs199474657     MT:3243      G  ENSG00000209082
# ...                    ...         ...    ...              ...
# 3941093        rs886037859  19:1220449      G  ENSG00000118046
# 3948139        rs121434498  19:4117551      C  ENSG00000126934
# 3948140        rs121434498  19:4117551      C  ENSG00000126934
# 3948141        rs121434498  19:4117551      C  ENSG00000126934
# 3948142        rs121434498  19:4117551      C  ENSG00000126934
#
#                  Feature Feature_type                         Consequence  \
# 2501     ENST00000361390   Transcript               upstream_gene_variant
# 2502     ENST00000361453   Transcript               upstream_gene_variant
# 2503     ENST00000361624   Transcript               upstream_gene_variant
# 2504     ENST00000361739   Transcript               upstream_gene_variant
# 2505     ENST00000386347   Transcript  non_coding_transcript_exon_variant
# ...                  ...          ...                                 ...
# 3941093  ENST00000714323   Transcript                    missense_variant
# 3948139  ENST00000262948   Transcript                    missense_variant
# 3948140  ENST00000394867   Transcript  non_coding_transcript_exon_variant
# 3948141  ENST00000599345   Transcript  non_coding_transcript_exon_variant
# 3948142  ENST00000687128   Transcript  non_coding_transcript_exon_variant
#
#         cDNA_position CDS_position Protein_position  ...  MAX_AF_POPS  \
# 2501                -            -                -  ...            -
# 2502                -            -                -  ...            -
# 2503                -            -                -  ...            -
# 2504                -            -                -  ...            -
# 2505               14            -                -  ...            -
# ...               ...          ...              ...  ...          ...
# 3941093          1669          541              181  ...            -
# 3948139           418          171               57  ...  gnomADe_ASJ
# 3948140           610            -                -  ...  gnomADe_ASJ
# 3948141           368            -                -  ...  gnomADe_ASJ
# 3948142           610            -                -  ...  gnomADe_ASJ
#
#                                                   CLIN_SIG    SOMATIC  \
# 2501     likely_pathogenic,pathogenic,not_provided,path...          -
# 2502     likely_pathogenic,pathogenic,not_provided,path...          -
# 2503     likely_pathogenic,pathogenic,not_provided,path...          -
# 2504     likely_pathogenic,pathogenic,not_provided,path...          -
# 2505     likely_pathogenic,pathogenic,not_provided,path...          -
# ...                                                    ...        ...
# 3941093                                  likely_pathogenic    0,1,1,1
# 3948139                                  likely_pathogenic  0,1,1,1,1
# 3948140                                  likely_pathogenic  0,1,1,1,1
# 3948141                                  likely_pathogenic  0,1,1,1,1
# 3948142                                  likely_pathogenic  0,1,1,1,1
#
#              PHENO                                             PUBMED  \
# 2501             1  25741868,33785019,16326995,26076356,20610441,2...
# 2502             1  25741868,33785019,16326995,26076356,20610441,2...
# 2503             1  25741868,33785019,16326995,26076356,20610441,2...
# 2504             1  25741868,33785019,16326995,26076356,20610441,2...
# 2505             1  25741868,33785019,16326995,26076356,20610441,2...
# ...            ...                                                ...
# 3941093    1,1,1,1                                           25741868
# 3948139  1,1,1,1,1       26619011,18456719,16439621,18042262,19156172
# 3948140  1,1,1,1,1       26619011,18456719,16439621,18042262,19156172
# 3948141  1,1,1,1,1       26619011,18456719,16439621,18042262,19156172
# 3948142  1,1,1,1,1       26619011,18456719,16439621,18042262,19156172
#
#         MOTIF_NAME MOTIF_POS HIGH_INF_POS MOTIF_SCORE_CHANGE  \
# 2501             -         -            -                  -
# 2502             -         -            -                  -
# 2503             -         -            -                  -
# 2504             -         -            -                  -
# 2505             -         -            -                  -
# ...            ...       ...          ...                ...
# 3941093          -         -            -                  -
# 3948139          -         -            -                  -
# 3948140          -         -            -                  -
# 3948141          -         -            -                  -
# 3948142          -         -            -                  -
#
#         TRANSCRIPTION_FACTORS
# 2501                        -
# 2502                        -
# 2503                        -
# 2504                        -
# 2505                        -
# ...                       ...
# 3941093                     -
# 3948139                     -
# 3948140                     -
# 3948141                     -
# 3948142                     -
#
# [1251 rows x 82 columns]

# %%
print("Variants with pathogenicity:", df_patho["Uploaded_variation"].nunique())
# Out:
# Variants with pathogenicity: 196

# %%
print("Variants with likely pathogenicity:", df_likely_patho["Uploaded_variation"].nunique())
# Out:
# Variants with likely pathogenicity: 73

# %%
#No. of variants per chromosome
df[['chr', 'position']] = df['Location'].str.split(':', expand=True)
df["chr"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #No. of variants per chromosome
# ----> 2 df[['chr', 'position']] = df['Location'].str.split(':', expand=True)
#       3 df["chr"].value_counts()
#
# NameError: name 'df' is not defined

# %%
# Identify rows that do NOT start with 'rs'
no_rs = df[~df['Uploaded_variation'].str.startswith('rs', na=False)]

# Optional: rows with rsIDs
with_rs = df[df['Uploaded_variation'].str.startswith('rs', na=False)]

# Print or save
print("Variants without rsIDs:")
no_rs["Uploaded_variation"].nunique()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("Variants with rsIDs:")
with_rs["Uploaded_variation"].nunique()
